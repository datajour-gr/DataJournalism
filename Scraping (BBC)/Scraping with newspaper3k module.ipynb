# %% [markdown]
# # **Scraping με το newspaper3k**

# %% [markdown]
# Scraping, είναι η διαδικασία με την οποία συλλέγουμε περιεχόμενο από ιστοσελίδες στο διαδίκτυο.
#
# Με όρους προγραμματισμού, η διαδικασία είναι η εξής:
# - κάνουμε ένα αίτημα στο server της ιστοσελίδας: ορίζουμε το url της ιστοσελίδας και ζητάμε το περιεχόμενό της (δηλαδή τον html κώδικά της)
# - κατεβάζουμε τον html κώδικα (στον οποίο το περιεχόμενο είναι οργανωμένο μέσα σε html tags)
# - παίρνουμε το περιεχόμενο από τα tags που μας ενδιαφέρουν και το αποθηκεύουμε σε αντίστοιχες μεταβλητές (π.χ. αν πρόκειται για δημοσιογραφικό άρθρο, παίρνουμε τον τίτλο του, το κείμενο, τον συγγραφέα, την ημερομηνία δημοσίευσής του κλπ.)
#
# Στη συνέχεια, μπορούμε να οργανώσουμε όλες τις πληροφορίες που συλλέξαμε σε ένα dataframe για να τις επεξεργαστούμε και να τις αναλύσουμε.
#
# Το **newspaper** είναι ένα πακέτο για την python, με το οποίο μπορούμε με εύκολο τρόπο να συλλέξουμε περιεχόμενο από ειδησεογραφικές ιστοσελίδες.
#
#
#
# ---
#
#
# Sources:
# - Documentation: https://newspaper.readthedocs.io/en/latest/
# - Scraping websites with Newspaper3k in Python: https://www.geeksforgeeks.org/scraping-websites-with-newspaper3k-in-python/
# - Scrape and Summarize News Articles in 5 Lines of Python Code: https://towardsdatascience.com/scrape-and-summarize-news-articles-in-5-lines-of-python-code-175f0e5c7dfc

# %% [markdown]
# ### **Εγκατάσταση πακέτου**

# %% [markdown]
# Ξέρουμε ότι για να μπορούμε να χρησιμοποιήσουμε τις συναρτήσεις ενός πακέτου πρέπει πρώτα να το εισάγουμε.

# %%
import newspaper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-83b806c39519> in <cell line: 1>()
# ----> 1 import newspaper
#
# ModuleNotFoundError: No module named 'newspaper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Η εκτέλεση του παραπάνω import επέστρεψε ModuleNotFoundError, που σημαίνει ότι δεν βρέθηκε το πακέτο newspaper. Άρα πρέπει πρώτα να το εγκαταστήσουμε.
#
# Εκτελούμε την παρακάτω εντολή εγκατάστασης και **αφού εγκατασταθεί το μετατρέπουμε σε σχόλιο** (βάζοντας στην αρχή της εντολής #).

# %%
#!pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (8.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.2)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.27.1)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.4.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.12.0)

# %% [markdown]
# Τώρα μπορούμε να εισάγουμε το newspaper.

# %% [markdown]
# ### **Χρήση του newspaper και συλλογή άρθρων**

# %%
import newspaper

# %% [markdown]
# Όπως είπαμε παραπάνω, στην περιγραφή των βημάτων για το scraping, το πρώτο πράγμα που πρέπει να κάνουμε είναι να ορίσουμε το url της ειδησεογραφικής σελίδας από την οποία θα αντλήσουμε τα περιεχόμενα.
#
# Εδώ, θα συλλέξουμε άρθρα από την κατηγορία news του bbc.

# %%
site_url = "https://www.bbc.com/news"

# %%
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] Exceeded 30 redirects.

# %%
# get list of article URLs
urlsL = site.article_urls()

print(len(urlsL))
# print the first 10 articles urls
urlsL[:10]
# Out:
# 299
# ['https://www.bbc.com/news/world-60525350',
#  'https://www.bbc.com/news/topics/c9wl4m5rqmlt',
#  'https://www.bbc.com/news/science-environment-56837908',
#  'https://www.bbc.com/news/av/10462520',
#  'https://www.bbc.com/news/world',
#  'https://www.bbc.com/news/world/us_and_canada',
#  'https://www.bbc.com/news/uk',
#  'https://www.bbc.com/news/business',
#  'https://www.bbc.com/news/technology',
#  'https://www.bbc.com/news/science_and_environment']

# %% [markdown]
# Έχουμε λοιπόν urls από το bbc.com/news.
#
# Τώρα, ας φέρουμε κάποια από τα άρθρα που υπάρχουν σε αυτά τα urls.

# %%
# import libraries
from newspaper import Article
import pandas as pd
import numpy as np

# %% [markdown]
# Για αρχή, ας φέρουμε το περιεχόμενο μόνο ενός άρθρου από το πρώτο url

# %%
article = Article(urlsL[0])
article.download()
article.parse()

# %% [markdown]
# Με τις παραπάνω εντολές, έχουμε κατεβάσει το πρώτο άρθρο και τώρα μπορούμε να δούμε το περιεχόμενό του. Ας δούμε τι έχουμε:

# %%
article.title
# Out:
# 'War in Ukraine'

# %%
article.text
# Out:
# 'No casualties are being reported from the air strikes which are said to have targeted Kyiv.\n\nRead more next'

# %%
article.authors
# Out:
# []

# %%
article.top_image
# Out:
# 'https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png'

# %%
article.images
# Out:
# {'...',
#  'https://a1.api.bbc.co.uk/hit.xiti?&col=1&from=p&ptag=js&s=598253&p=unknown&x2=[responsive]&x3=[bbc_website]&x4=[en]&x7=[index-section]&x8=[reverb-3.6.1-nojs]&x11=[news_gnl]&x12=[news]',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/10370/production/_129661466_3e38f3eb-ee42-4ad8-aa9e-a2a8fa36435a.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/10674/production/_129588176_gettyimages-1251900584.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/12AF7/production/_129653567_eurovision.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/12EC/production/_129644840_chuchcapture.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/1759C/production/_129644659_0d2b5133-fc1a-4e98-863a-0fbad0497f9b.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/2BBF/production/_129699111_08135fd08847f094374fd314c65ba84ef41e9c9a0_113_5186_29182000x1125.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/397B/production/_129651741_gettyimages-1253336600.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/3BE6/production/_129643351_mediaitem129643347.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/3D58/production/_129640751_tureuters.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/6B8A/production/_129703572_827277ad53a5d8b960a61cabcf5c54427af8b1ff0_210_3445_19381000x563.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/6F26/production/_129645482_f80316cb-05cd-4e58-9d58-08b23f8b72b6.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/822C/production/_129642333_ad3157351dd332c168d22fbd6a55be07d16c4f88.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/8502/production/_129705043_bakhmutre.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/9509/production/_127435183_whatsubject.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/9EC4/production/_129644604_maks5.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/AC68/production/_129663144_db648ed957a536a976a12ef0449fa856e8ec4983.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/B8EC/production/_129704374_eefc6d189439a67c9dea8ca760bde7d6da2b39250_128_5519_31061000x563.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/E9C6/production/_129664895_screenshot2023-05-10at22.59.44.jpg',
#  'https://ichef.bbci.co.uk/news/490/cpsprodpb/8502/production/_129705043_bakhmutre.jpg',
#  'https://sb.scorecardresearch.com/p?c1=2&c2=17986528&cs_ucfr=0&cv=2.0&cj=1',
#  'https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png',
#  'https://ychef.files.bbci.co.uk/width/320/p0fmsrzw.jpg'}

# %%
article.movies
# Out:
# []

# %%
article.publish_date

# %% [markdown]
# Αφού είδαμε ποιες πληροφορίες μπορούμε να πάρουμε για ένα url, ας φέρουμε αυτές τις πληροφορίες για τα 10 πρώτα urls κι ας τις οργανώσουμε σε ένα dataframe.

# %%
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)

# %%
news_df
# Out:
#                                                  url  date  \
# 0            https://www.bbc.com/news/world-60525350   NaN
# 1       https://www.bbc.com/news/topics/c9wl4m5rqmlt   NaN
# 2  https://www.bbc.com/news/science-environment-5...   NaN
# 3               https://www.bbc.com/news/av/10462520   NaN
# 4                     https://www.bbc.com/news/world   NaN
# 5       https://www.bbc.com/news/world/us_and_canada   NaN
# 6                        https://www.bbc.com/news/uk   NaN
# 7                  https://www.bbc.com/news/business   NaN
# 8                https://www.bbc.com/news/technology   NaN
# 9   https://www.bbc.com/news/science_and_environment   NaN
#
#                             title  \
# 0                  War in Ukraine
# 1  Coronation of King Charles III
# 2                        BBC News
# 3           One-minute World News
# 4                        BBC News
# 5                     US & Canada
# 6                        BBC News
# 7                        Business
# 8                      Technology
# 9           Science & Environment
#
#                                            top image  \
# 0  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 1  https://www.bbc.co.uk/news/special/2015/newssp...
# 2  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 3  https://ichef.bbci.co.uk/news/1024/branded_new...
# 4  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 5  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 6  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 7  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 8  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 9  https://static.files.bbci.co.uk/ws/simorgh-ass...
#
#                                                 text authors  \
# 0  No casualties are being reported from the air ...      []
# 1  Chris Mason: Debate around protest law is far ...      []
# 2  Israel's NT-Tao wants to build a compact fusio...      []
# 3  An American watches Eurovision for the first t...      []
# 4  Getty Images Copyright: Getty Images Peter Mat...      []
# 5  Viewers worldwide will be able to vote for the...      []
# 6  Celtic and Inverness say they are "disappointe...      []
# 7  It comes as a new survey suggests one in three...      []
# 8  Video caption: A 100-year-old man is learning ...      []
# 9  Some physiques perform better in different cli...      []
#
#                                               images movies
# 0  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 1  {https://ichef.bbci.co.uk/ace/standard/480/cps...     []
# 2  {......     []
# 3  {https://news.bbcimg.co.uk/media/images/483510...     []
# 4  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 5  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 6  {......     []
# 7  {......     []
# 8  {......     []
# 9  {......     []

# %% [markdown]
# Ολόκληρος ο κώδικας για να φέρουμε το περιεχόμενο των άρθρων από ένα site

# %%
# define site url
site_url = "https://www.bbc.com/news"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] Exceeded 30 redirects.

# %% [markdown]
# ## **Άσκηση:** χρησιμοποιήστε τον παραπάνω κώδικα για να φτιάξετε ένα dataframe με άρθρα από το news247 και την efsyn.

# %% [markdown]
# **news247**

# %%
# define site url
site_url = "https://www.news247.gr/latest/"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feeds

# %%
news_df
# Out:
#                                                  url  \
# 0  https://www.ladylike.gr/zodia/antigrafo-zodia-...
# 1  https://www.ladylike.gr/beauty/proti-fora-pou-...
# 2  https://www.ladylike.gr/style/10-idees-gia-dim...
# 3  https://www.ow.gr/ygeia/giati-vixoume-akoma-ka...
# 4  https://www.ow.gr/psychologia/6-fraseis-pou-de...
# 5  https://www.ow.gr/ygeia/ti-simainei-nosileia-k...
# 6  https://www.ow.gr/ygeia/ti-simainei-nosileia-k...
# 7  https://www.ow.gr/psychologia/6-fraseis-pou-de...
# 8  https://www.ow.gr/wellness/oi-aisthiseis-sou-e...
#
#                        date  \
# 0 2023-05-12 06:43:16+00:00
# 1 2023-05-11 14:35:45+00:00
# 2 2023-05-11 13:23:20+00:00
# 3 2023-05-12 06:30:54+00:00
# 4 2023-05-12 05:00:00+00:00
# 5 2023-05-12 04:30:49+00:00
# 6 2023-05-12 04:30:49+00:00
# 7 2023-05-12 05:00:00+00:00
# 8 2023-05-12 04:00:26+00:00
#
#                                                title  \
# 0  Ζώδια Σήμερα: Οι προβλέψεις από την Άση Μπήλιο...
# 1               Πρώτη φορά που έκανα brow lamination
# 2  10 ιδέες για δημιουργικά, νυφικά looks από τα ...
# 3       ΓΙΑΤΙ ΒΗΧΟΥΜΕ ΑΚΟΜΑ ΚΑΙ ΜΗΝΕΣ ΜΕΤΑ ΤΟ ΚΡΥΩΜΑ
# 4  6 ΦΡΑΣΕΙΣ ΠΟΥ ΔΕΙΧΝΟΥΝ ΟΤΙ ΕΧΕΙΣ ΑΠΕΝΑΝΤΙ ΣΟΥ ...
# 5  Τι είναι η νοσηλεία κατ' οίκον για τους ασθενε...
# 6  Τι είναι η νοσηλεία κατ' οίκον για τους ασθενε...
# 7  6 ΦΡΑΣΕΙΣ ΠΟΥ ΔΕΙΧΝΟΥΝ ΟΤΙ ΕΧΕΙΣ ΑΠΕΝΑΝΤΙ ΣΟΥ ...
# 8  ΟΙ ΑΙΣΘΗΣΕΙΣ ΣΟΥ ΕΧΟΥΝ ΜΕΓΑΛΥΤΕΡΗ ΔΥΝΑΜΗ ΑΠΟ Ο...
#
#                                            top image  \
# 0  https://media.ladylike.gr/ldl-images/zodia-d-4...
# 1   https://media.ladylike.gr/ldl-images/FRA2554.jpg
# 2  https://media.ladylike.gr/ldl-images/bridal-lo...
# 3    https://media.ow.gr/ow-images/2023/05/cough.jpg
# 4  https://media.ow.gr/ow-images/2023/05/narkisos...
# 5  https://media.ow.gr/ow-images/2024/08/nosileia...
# 6  https://media.ow.gr/ow-images/2024/08/nosileia...
# 7  https://media.ow.gr/ow-images/2023/05/narkisos...
# 8   https://media.ow.gr/ow-images/2023/05/senses.jpg
#
#                                                 text  \
# 0  Το LadyLike σε συνεργασία με την Άση Μπήλιου κ...
# 1  Αν κάτι έμεινε στο κεφάλι μου από τη δεκαετία ...
# 2  Όταν η Keira Knightley παντρεύτηκε το 2013 τον...
# 3  Ένας επίμονος βήχας μετά από κρυολόγημα ή λοίμ...
# 4  Υπάρχουν διάφορα σημάδια για να καταλάβεις ότι...
# 5  Αν μπορούσε κανείς να μπει στη θέση ενός ασθεν...
# 6  Αν μπορούσε κανείς να μπει στη θέση ενός ασθεν...
# 7  Υπάρχουν διάφορα σημάδια για να καταλάβεις ότι...
# 8  Το «ό,τι αφήνεις σε αφήνει» ισχύει και για τις...
#
#                                              authors  \
# 0                         [Άση Μπήλιου, Αση Μπηλιου]
# 1                     [Βιβή Αγγελάκη, Βιβη Αγγελακη]
# 2     [Τζώρτζια Παρασκευούδη, Τζωρτζια Παρασκευουδη]
# 3     [Ν. Μπάκουλη, Μ. Γκόγκου, Ε. Ξενάκη, Κ. Σώκου]
# 4     [Ν. Μπάκουλη, Κ. Σώκου, Ε. Ξενάκη, Μ. Γκόγκου]
# 5     [Μ. Γκόγκου, Ν. Μπάκουλη, Ε. Ξενάκη, Κ. Σώκου]
# 6     [Μ. Γκόγκου, Ν. Μπάκουλη, Ε. Ξενάκη, Κ. Σώκου]
# 7     [Ν. Μπάκουλη, Κ. Σώκου, Ε. Ξενάκη, Μ. Γκόγκου]
# 8  [Ν. Μπάκουλη, Ε. Ξενάκη, Μ. Γκόγκου, Μ. Παπαδο...
#
#                                               images movies
# 0  {https://media.ladylike.gr/ldl-images/scared-6...     []
# 1  {https://media.ladylike.gr/ldl-images/ladylike...     []
# 2  {https://media.ladylike.gr/ldl-images/Doucan-S...     []
# 3  {https://media.ow.gr/ow-images/2021/10/24media...     []
# 4  {https://media.ow.gr/ow-images/2021/10/24media...     []
# 5  {https://media.ow.gr/ow-images/2024/08/nosilei...     []
# 6  {https://media.ow.gr/ow-images/2024/08/nosilei...     []
# 7  {https://media.ow.gr/ow-images/2021/10/24media...     []
# 8  {https://media.ow.gr/ow-images/2021/10/24media...     []

# %% [markdown]
# **efsyn**

# %%
# define site url
site_url = "https://www.efsyn.gr/"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feeds

# %%
news_df
# Out:
#                                                  url  date  \
# 0                  https://www.efsyn.gr/tehnes/media   NaN
# 1  https://www.efsyn.gr/politiki/antipoliteysi/38...   NaN
# 2  https://www.efsyn.gr/politiki/kybernisi/389383...   NaN
# 3  https://www.efsyn.gr/politiki/antipoliteysi/38...   NaN
# 4  https://www.efsyn.gr/politiki/antipoliteysi/38...   NaN
# 5  https://www.efsyn.gr/politiki/antipoliteysi/38...   NaN
# 6  https://www.efsyn.gr/politiki/389371_ola-osa-p...   NaN
# 7  https://www.efsyn.gr/politiki/kybernisi/389364...   NaN
# 8  https://www.efsyn.gr/politiki/antipoliteysi/38...   NaN
# 9  https://www.efsyn.gr/politiki/ekloges/389347_o...   NaN
#
#                                                title  \
# 0                                              Media
# 1  ΚΚΕ(μ-λ): Αποκαλύψεις... για να κλιμακωθεί η ε...
# 2  Κινδυνολογία και success story από Μητσοτάκη σ...
# 3  Κουτσούμπας: ΚΚΕ για να χαμογελάσει η νεολαία ...
# 4  «Είμαι ο μόνος ΥΠΟΙΚ που μελέτησα τα μνημόνια ...
# 5  Σφυροκόπημα σε Μητσοτάκη, «καρφί» και σε Ανδρο...
# 6       Όλα όσα πρέπει να γνωρίζουμε για τις εκλογές
# 7  Θλιβερή απόπειρα να δικαιολογηθεί το στραπάτσο...
# 8  Νέα καταγγελία ΜέΡΑ25 για Mega περί αποκλεισμο...
# 9  Οι Έλληνες του εξωτερικού θα ψηφίσουν στις 20 ...
#
#                                            top image  \
# 0  https://www.efsyn.gr/themes/custom/efsyn/image...
# 1  https://www.efsyn.gr/sites/default/files/style...
# 2  https://www.efsyn.gr/sites/default/files/style...
# 3  https://www.efsyn.gr/sites/default/files/style...
# 4  https://www.efsyn.gr/sites/default/files/style...
# 5  https://www.efsyn.gr/sites/default/files/style...
# 6  https://www.efsyn.gr/sites/default/files/style...
# 7  https://www.efsyn.gr/sites/default/files/style...
# 8  https://www.efsyn.gr/sites/default/files/style...
# 9  https://www.efsyn.gr/sites/default/files/style...
#
#                                                 text authors  \
# 0  MEDIA Τέλος από το Open ο Γιάννης Λάτσιος Ήταν...      []
# 1  efsyn\n\nΤις παρεμβάσεις του Γιάννη Στουρνάρα ...      []
# 2  efsyn\n\n«Λένε κάποιοι ότι αυτές οι εκλογές εί...      []
# 3  efsyn.gr\n\nΟ γγ της ΚΕ του ΚΚΕ, Δημήτρης Κουτ...      []
# 4  efsyn.gr\n\n«Είμαι περήφανος για το 2015. Είμα...      []
# 5  efsyn\n\nΟλομέτωπη επίθεση στον Κυριάκο Μητσοτ...      []
# 6  efsyn\n\nΠληροφορίες και οδηγίες για τη διενέρ...      []
# 7  efsyn.gr\n\nΑπίστευτες δικαιολογίες από τον Άκ...      []
# 8  efsyn.gr\n\nΟ υποψήφιος βουλευτής του κόμματος...      []
# 9  efsyn. gr\n\nΤο Σάββατο 20 Μαΐου θα προσέλθουν...      []
#
#                                               images movies
# 0  {......     []
# 1  {......     []
# 2  {https://www.efsyn.gr/sites/default/files/styl...     []
# 3  {https://www.efsyn.gr/sites/default/files/styl...     []
# 4  {https://www.efsyn.gr/sites/default/files/styl...     []
# 5  {https://www.efsyn.gr/themes/custom/efsyn/imag...     []
# 6  {https://www.efsyn.gr/sites/default/files/styl...     []
# 7  {https://www.efsyn.gr/sites/default/files/styl...     []
# 8  {https://www.efsyn.gr/sites/default/files/styl...     []
# 9  {https://www.efsyn.gr/sites/default/files/styl...     []
